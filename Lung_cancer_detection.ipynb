# %% [markdown]
# # Lung Cancer Detection

# %% [markdown]
# Considering various factors like GENDER, AGE, SMOKING, YELLOW FINGERS, ANXIETY, PEER PRESSURE, CHRONIC DISEASE, FATIGUE, ALLERGY WHEEZING, ALCOHOL CONSUMING, COUGHING, SHORTNESS OF BREATH,SWALLOWING DIFFICULTY, CHEST PAIN

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from IPython import get_ipython
import warnings
warnings.filterwarnings("ignore")
from sklearn import preprocessing

# %%
# importing datasets
df = pd.read_csv(r"C:\Users\sevan\Jupyter Projects\Lung cancer detection\survey lung cancer.csv")

# %%
# understanding the dataset by prinintg out first and last 5 rows
df.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# ...

# %%
df.tail()
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 304                2         2         1         1                  2
# 305                1         2         2         2                  2
# 306                1         1         2         2                  2
# 307                1         2         2         1                  2
# 308                1         2         2         2                  2
#
#      COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 304         2                    2                      2           1
# ...

# %%
# attributes present in the dataset
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
# no. of rows and columns
df.shape
# Out:
# (309, 16)

# %%
# sum of duplicates present in the dataset
df.duplicated().sum()
# Out:
# 33

# %%
# deleting/dropping the duplicate values
data = df.drop_duplicates()

# %%
# any null values present in the dataset
data.isnull().sum()
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL CONSUMING        0
# COUGHING                 0
# SHORTNESS OF BREATH      0
# SWALLOWING DIFFICULTY    0
# CHEST PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
# count, mean and other statistical values of dataset
data.describe()
# Out:
#               AGE     SMOKING  YELLOW_FINGERS     ANXIETY  PEER_PRESSURE  \
# count  276.000000  276.000000      276.000000  276.000000     276.000000
# mean    62.909420    1.543478        1.576087    1.496377       1.507246
# std      8.379355    0.499011        0.495075    0.500895       0.500856
# min     21.000000    1.000000        1.000000    1.000000       1.000000
# 25%     57.750000    1.000000        1.000000    1.000000       1.000000
# 50%     62.500000    2.000000        2.000000    1.000000       2.000000
# 75%     69.000000    2.000000        2.000000    2.000000       2.000000
# max     87.000000    2.000000        2.000000    2.000000       2.000000
#
#        CHRONIC DISEASE    FATIGUE     ALLERGY     WHEEZING  ALCOHOL CONSUMING  \
# count       276.000000  276.000000  276.000000  276.000000         276.000000
# mean          1.521739    1.663043    1.547101    1.547101           1.550725
# ...

# %%
# understaing the datasets, knowing the value count of all the attributes and any null values if present
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 276 entries, 0 to 283
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 276 non-null    object
#  1   AGE                    276 non-null    int64
#  2   SMOKING                276 non-null    int64
#  3   YELLOW_FINGERS         276 non-null    int64
#  4   ANXIETY                276 non-null    int64
#  5   PEER_PRESSURE          276 non-null    int64
#  6   CHRONIC DISEASE        276 non-null    int64
#  7   FATIGUE                276 non-null    int64
#  8   ALLERGY                276 non-null    int64
#  9   WHEEZING               276 non-null    int64
#  10  ALCOHOL CONSUMING      276 non-null    int64
#  11  COUGHING               276 non-null    int64
#  12  SHORTNESS OF BREATH    276 non-null    int64
#  13  SWALLOWING DIFFICULTY  276 non-null    int64
#  14  CHEST PAIN             276 non-null    int64
# ...

# %%
# Label encoidng the object values
le= preprocessing.LabelEncoder()

# %%
# gender and lung_cancer are present in object values, we are converting them to numerical values
data['GENDER']= le.fit_transform(data['GENDER'])
data['LUNG_CANCER']=le.fit_transform(data['LUNG_CANCER'])

# %%
# number of unique values for every given attribute
data.nunique()
# Out:
# GENDER                    2
# AGE                      39
# SMOKING                   2
# YELLOW_FINGERS            2
# ANXIETY                   2
# PEER_PRESSURE             2
# CHRONIC DISEASE           2
# FATIGUE                   2
# ALLERGY                   2
# WHEEZING                  2
# ALCOHOL CONSUMING         2
# COUGHING                  2
# SHORTNESS OF BREATH       2
# SWALLOWING DIFFICULTY     2
# CHEST PAIN                2
# LUNG_CANCER               2
# dtype: int64

# %%
# rechecking the dataset information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 276 entries, 0 to 283
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 276 non-null    int32
#  1   AGE                    276 non-null    int64
#  2   SMOKING                276 non-null    int64
#  3   YELLOW_FINGERS         276 non-null    int64
#  4   ANXIETY                276 non-null    int64
#  5   PEER_PRESSURE          276 non-null    int64
#  6   CHRONIC DISEASE        276 non-null    int64
#  7   FATIGUE                276 non-null    int64
#  8   ALLERGY                276 non-null    int64
#  9   WHEEZING               276 non-null    int64
#  10  ALCOHOL CONSUMING      276 non-null    int64
#  11  COUGHING               276 non-null    int64
#  12  SHORTNESS OF BREATH    276 non-null    int64
#  13  SWALLOWING DIFFICULTY  276 non-null    int64
#  14  CHEST PAIN             276 non-null    int64
# ...

# %%
data.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
# plotting graphs for all the different attributes and their count
for i in data.columns:
    plt.figure(figsize=(10,6))
    sns.countplot(data[i], data =data,
    palette = 'hls')
    plt.xticks(rotation = 90)
    plt.show()

# %%
# pie charts for all the attributes
for i in data.columns:
    data[i].value_counts().plot(kind='pie',
    figsize=(8,8),
    autopct='%1.1f%%')
    plt.xticks(rotation = 90)
    plt.show()

# %%
# plot of patients haing yellow fingers and lung cancer
plt.figure(figsize=(10,4))
sns.countplot(data=data,x='YELLOW_FINGERS',hue='LUNG_CANCER')
plt.legend(["Has cancer", 'Does not have cancer'])
plt.xticks(rotation = 90)
plt.show()

# %%
# plot of patients coughing having lung cancer
plt.figure(figsize=(10,4))
sns.countplot(data=data,x='COUGHING',hue='LUNG_CANCER')
plt.legend(["Has cancer", 'Does not have cancer'])
plt.xticks(rotation = 90)
plt.show()

# %%
# plot of patients having shortness of breath having lung cancer
plt.figure(figsize=(10,4))
sns.countplot(data=data,x='SHORTNESS OF BREATH',hue='LUNG_CANCER')
plt.legend(["Has cancer", 'Does not have cancer'])
plt.xticks(rotation = 90)
plt.show()

# %%
#plot of patients having anxiety having lung cancer
plt.figure(figsize=(10,4))
sns.countplot(data=data,x='ANXIETY',hue='SHORTNESS OF BREATH')
plt.legend(["Has cancer", 'Does not have cancer'])
plt.xticks(rotation = 90)
plt.show()

# %%
# correlation between all the attributes
corrmat = data.corr()
corrmat
# Out:
#                          GENDER       AGE   SMOKING  YELLOW_FINGERS   ANXIETY  \
# GENDER                 1.000000 -0.013120  0.041131       -0.202506 -0.152032
# AGE                   -0.013120  1.000000 -0.073410        0.025773  0.050605
# SMOKING                0.041131 -0.073410  1.000000       -0.020799  0.153389
# YELLOW_FINGERS        -0.202506  0.025773 -0.020799        1.000000  0.558344
# ANXIETY               -0.152032  0.050605  0.153389        0.558344  1.000000
# PEER_PRESSURE         -0.261427  0.037848 -0.030364        0.313067  0.210278
# CHRONIC DISEASE       -0.189925 -0.003431 -0.149415        0.015316 -0.006938
# FATIGUE               -0.079020  0.021606 -0.037803       -0.099644 -0.181474
# ALLERGY                0.150174  0.037139 -0.030179       -0.147130 -0.159451
# WHEEZING               0.121047  0.052803 -0.147081       -0.058756 -0.174009
# ALCOHOL CONSUMING      0.434264  0.052049 -0.052771       -0.273643 -0.152228
# ...

# %%
# heatmap
cmap = sns.diverging_palette(210,10,s=50, l=85, n=1,
as_cmap=True)
plt.subplots(figsize=(18,18))
sns.heatmap(corrmat,cmap= cmap,annot=True, square=True)
plt.show()

# %%
# plotting lung cancer on y axis and rest all attributes on x axis
x = data.drop('LUNG_CANCER', axis = 1)
y = data['LUNG_CANCER']

# %%
# splitting the given dataset to train and test dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(x, y,test_size= 0.25,random_state=0)

# %%
# fitting to logistic regression
from sklearn.linear_model import LogisticRegression
classifier= LogisticRegression(random_state=0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
# predictions of y axis
y_pred= classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, mean_absolute_error , mean_squared_error, median_absolute_error, r2_score, confusion_matrix, classification_report

# %%
print("Mean absolute error is ",( mean_absolute_error(y_test,y_pred)))
print("Mean squared error is " , mean_squared_error(y_test,y_pred))
print("Median absolute error is " ,median_absolute_error(y_test,y_pred))
print("R2 Score is " , r2_score(y_test,y_pred))
print("Accuracy is " , round(accuracy_score(y_test,y_pred)*100,2),"%")
# Out:
# Mean absolute error is  0.10144927536231885
# Mean squared error is  0.10144927536231885
# Median absolute error is  0.0
# R2 Score is  0.10555555555555596
# Accuracy is  89.86 %

# %%
# classification report
tp, fn, fp, tn = confusion_matrix(y_test,y_pred,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)
matrix = classification_report(y_test,y_pred,labels=[1,0])
print('Classification report : \n',matrix)
# Out:
# Outcome values :
#  56 4 3 6
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.95      0.93      0.94        60
#            0       0.60      0.67      0.63         9
#
#     accuracy                           0.90        69
#    macro avg       0.77      0.80      0.79        69
# weighted avg       0.90      0.90      0.90        69

# %%
# confusion matrix
matrix = confusion_matrix(y_test, y_pred, labels=[1,0])
print('Confusion matrix : \n',matrix)
# Out:
# Confusion matrix :
#  [[56  4]
#  [ 3  6]]
